# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorYuzoBR/learning-phyton/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !bash Miniconda3-latest-Linux-x86_64.sh -b -p /usr/local/miniconda
# !rm Miniconda3-latest-Linux-x86_64.sh
# Out:
# --2024-09-08 21:18:47--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 148981743 (142M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>] 142.08M   138MB/s    in 1.0s
#
# 2024-09-08 21:18:48 (138 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [148981743/148981743]
#
# PREFIX=/usr/local/miniconda
# Unpacking payload ...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
# ...

# %%
import sys
import os
sys.path.append('/usr/local/miniconda/bin')
os.environ['PATH'] = '/usr/local/miniconda/bin:' + os.environ['PATH']

# %%
# !conda --version
# Out:
# conda 24.7.1

# %%
# !conda create -y --name myenv python=3.8
# !source activate myenv
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/miniconda/envs/myenv
#
#   added / updated specs:
#     - python=3.8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-3.0.15             |       h5eee18b_0         5.2 MB
#     pip-24.2                   |   py38h06a4308_0         2.2 MB
#     python-3.8.19              |       h955ad1f_0        23.8 MB
#     setuptools-72.1.0          |   py38h06a4308_0         2.4 MB
#     wheel-0.43.0               |   py38h06a4308_0         109 KB
#     ------------------------------------------------------------
#                                            Total:        33.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
# ...

# %%
# !source deactivate

# %%
# !source activate myenv
# Out:
# /bin/bash: line 1: activate: No such file or directory

# %%
# !conda install -y numpy scipy pandas matplotlib scikit-learn
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/miniconda
#
#   added / updated specs:
#     - matplotlib
#     - numpy
#     - pandas
#     - scikit-learn
#     - scipy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     bottleneck-1.3.7           |  py312ha883a20_0         140 KB
#     brotli-1.0.9               |       h5eee18b_8          18 KB
#     brotli-bin-1.0.9           |       h5eee18b_8          19 KB
#     certifi-2024.8.30          |  py312h06a4308_0         163 KB
#     contourpy-1.2.0            |  py312hdb19cb5_0         238 KB
#     cycler-0.11.0              |     pyhd3eb1b0_0          12 KB
#     cyrus-sasl-2.1.28          |       h52b45da_1         237 KB
# ...

# %%
import numpy as np
import scipy
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
print("Instalações bem-sucedidas!")
# Out:
# Instalações bem-sucedidas!

# %% [markdown]
#  Exerc´ıcios de Pandas
# 1. Crie um DataFrame contendo as colunas Produto, Pre¸co e Quantidade
# com 5 produtos.
# 2. Leia um arquivo Excel chamado vendas.xlsx e exiba as 10 primeiras
# linhas.
# 3. Filtre um DataFrame para exibir apenas os valores onde a coluna Pre¸co
# ´e maior que 100.
# 4. Adicione uma coluna chamada Desconto ao DataFrame com 10% de desconto para todos os produtos.
# 5. Remova as linhas do DataFrame que contenham valores nulos.
# 6. Ordene o DataFrame pela coluna Produto em ordem alfab´etica.
# 7. Crie uma nova coluna chamada Total que seja o produto entre as colunas
# Pre¸co e Quantidade.
# 8. Agrupe o DataFrame pela coluna Categoria e calcule o total de produtos
# por categoria.
# 9. Exporte o DataFrame resultante para um arquivo CSV chamado resultados.csv.
# 10. Leia um arquivo CSV, renomeie as colunas e exiba as 5 ´ultimas linhas do
# DataFrame.
# 11. Preencha os valores nulos de uma coluna num´erica com a mediana dessa
# coluna.
# 12. Verifique quais colunas de um DataFrame contˆem valores duplicados.
# 13. Crie uma tabela dinˆamica a partir do DataFrame, calculando a soma de
# Quantidade por Categoria.
# 14. Mescle dois DataFrames baseados em uma coluna comum chamada ID
# utilizando um join.
# 15. Crie um DataFrame com dados faltantes e use a interpola¸c˜ao linear para
# preenchˆe-los.
# 16. Crie um gr´afico de barras a partir de um DataFrame usando a biblioteca
# Pandas.
# 17. Adicione uma coluna ao DataFrame que calcule o imposto (5%) sobre o
# valor da coluna Total.
# 18. Exiba apenas as linhas de um DataFrame onde o nome do produto come¸ca
# com a letra ”B”.
# 5
# 19. Crie um DataFrame a partir de um dicion´ario de listas e calcule a m´edia
# de cada coluna num´erica.
# 20. Agrupe os dados por uma coluna categ´orica e calcule a mediana de uma
# coluna num´erica.

# %%
import pandas as pd

# Criar um DataFrame
dados = {'produto': ['teste1','teste2','teste3','teste4','teste4'] ,
'preco': [23 , 35 , 45 , 28, 5] ,
'quantidade': [1,2,3,4,5]}
df = pd.DataFrame(dados)
print ( df )
# Out:
#   produto  preco  quantidade
# 0  teste1     23           1
# 1  teste2     35           2
# 2  teste3     45           3
# 3  teste4     28           4
# 4  teste4      5           5

# %%
df = pd.read_excel("vendas.xlsx")
teste = df.loc[:10]
print(teste)
# Out:
#    id produto    quant
# 0   1     asd       12
# 1   2     asd       45
# 2   3     sdf      789
# 3   4     asd      456
# 4   5     sdf      789
# 5   6     sdf  4563465
# 6   7     asd     3213
# 7   8     sdf      546
# 8   9     asd      789

# %%
import pandas as pd

# Criar um DataFrame
dados = {'produto': ['teste1','teste2','teste3','teste4','teste4'] ,
'preco': [23 , 120 , 102 , 28, 5] ,
'quantidade': [1,2,3,4,5]}
df = pd.DataFrame(dados)
print ( df )
print()
precogrande = df[df['preco'] > 100 ]
print(precogrande)
# Out:
#   produto  preco  quantidade
# 0  teste1     23           1
# 1  teste2    120           2
# 2  teste3    102           3
# 3  teste4     28           4
# 4  teste4      5           5
#
#   produto  preco  quantidade
# 1  teste2    120           2
# 2  teste3    102           3

# %%
import pandas as pd

# Criar um DataFrame
dados = {'produto': ['teste1','teste2','teste3','teste4','teste4'] ,
'preco': [23 , 120 , 102 , 28, 5] ,
'quantidade': [1,2,3,4,5]}
df = pd.DataFrame(dados)
print ( df )
print()
df['desconto'] = [10,10,10,10,10]
print(df)
# Out:
#   produto  preco  quantidade
# 0  teste1     23           1
# 1  teste2    120           2
# 2  teste3    102           3
# 3  teste4     28           4
# 4  teste4      5           5
#
#   produto  preco  quantidade  desconto
# 0  teste1     23           1        10
# 1  teste2    120           2        10
# 2  teste3    102           3        10
# 3  teste4     28           4        10
# 4  teste4      5           5        10

# %%
import pandas as pd

# Criar um DataFrame
dados = {'produto': [pd.NaT,'teste2','teste3','teste4','teste4'] ,
'preco': [23 , np.nan , 102 , 0, 5] ,
'quantidade': [1,2,3,4,5]}
df = pd.DataFrame(dados)
print ( df )
print()
df = df.dropna()
print(df)
# Out:
#   produto  preco  quantidade
# 0     NaT   23.0           1
# 1  teste2    NaN           2
# 2  teste3  102.0           3
# 3  teste4    0.0           4
# 4  teste4    5.0           5
#
#   produto  preco  quantidade
# 2  teste3  102.0           3
# 3  teste4    0.0           4
# 4  teste4    5.0           5

# %%
import pandas as pd

# Criar um DataFrame
dados = {'produto': ['carro','teste2','bola','teste4','mesa'] ,
'preco': [23 , 120 , 102 , 28, 5] ,
'quantidade': [1,2,3,4,5]}
df = pd.DataFrame(dados)
print ( df )
print()
df = df.sort_values(by="produto")
print(df)
# Out:
#   produto  preco  quantidade
# 0   carro     23           1
# 1  teste2    120           2
# 2    bola    102           3
# 3  teste4     28           4
# 4    mesa      5           5
#
#   produto  preco  quantidade
# 2    bola    102           3
# 0   carro     23           1
# 4    mesa      5           5
# 1  teste2    120           2
# 3  teste4     28           4

# %%
import pandas as pd

# Criar um DataFrame
dados = {'produto': ['carro','teste2','bola','teste4','mesa'] ,
'preco': [23 , 120 , 102 , 28, 5] ,
'quantidade': [1,2,3,4,5]}
df = pd.DataFrame(dados)
print ( df )
print()
total = df.quantidade * df.preco
print(total)
# Out:
#   produto  preco  quantidade
# 0   carro     23           1
# 1  teste2    120           2
# 2    bola    102           3
# 3  teste4     28           4
# 4    mesa      5           5
#
# 0     23
# 1    240
# 2    306
# 3    112
# 4     25
# dtype: int64

# %%
import pandas as pd

# Criar um DataFrame
dados = {'produto': ['carro','teste2','bola','teste4','mesa'] ,
'preco': [23 , 120 , 102 , 28, 5] ,
'quantidade': [1,2,3,4,5],
'categoria':['veiculo','veiculo','comida','comida','veiculo']         }
df = pd.DataFrame(dados)
print ( df )
print()
df = df.groupby(['categoria'])['produto'].count()
print(df)
# Out:
#   produto  preco  quantidade categoria
# 0   carro     23           1   veiculo
# 1  teste2    120           2   veiculo
# 2    bola    102           3    comida
# 3  teste4     28           4    comida
# 4    mesa      5           5   veiculo
#
# categoria
# comida     2
# veiculo    3
# Name: produto, dtype: int64

# %%
import pandas as pd

# Criar um DataFrame
dados = {'produto': ['carro','teste2','bola','teste4','mesa'] ,
'preco': [23 , 120 , 102 , 28, 5] ,
'quantidade': [1,2,3,4,5],
'categoria':['veiculo','veiculo','comida','comida','veiculo']         }
df = pd.DataFrame(dados)
print ( df )

df.to_csv('resultado.csv', index=False)
# Out:
#   produto  preco  quantidade categoria
# 0   carro     23           1   veiculo
# 1  teste2    120           2   veiculo
# 2    bola    102           3    comida
# 3  teste4     28           4    comida
# 4    mesa      5           5   veiculo

# %%
import pandas as pd

df = pd.read_csv("resultado.csv")
print(df)
print()

df.rename({"produto":"PRODUCT", "preco":"PRICE"},axis=1, inplace=True)

print(df[:3])
# Out:
#   produto  preco  quantidade categoria
# 0   carro     23           1   veiculo
# 1  teste2    120           2   veiculo
# 2    bola    102           3    comida
# 3  teste4     28           4    comida
# 4    mesa      5           5   veiculo
#
#   PRODUCT  PRICE  quantidade categoria
# 0   carro     23           1   veiculo
# 1  teste2    120           2   veiculo
# 2    bola    102           3    comida

# %%
import pandas as pd

# Criar um DataFrame
dados = {'produto': ['carro','teste2','bola','teste4','mesa'] ,
'preco': [23 , np.nan , 102 , 28, np.nan] ,
'quantidade': [1,2,3,4,5],
'categoria':['veiculo','veiculo','comida','comida','veiculo']         }
df = pd.DataFrame(dados)
print ( df )

df["preco"] = df["preco"].fillna(df["preco"].mean())
print()
print(df)
# Out:
#   produto  preco  quantidade categoria
# 0   carro   23.0           1   veiculo
# 1  teste2    NaN           2   veiculo
# 2    bola  102.0           3    comida
# 3  teste4   28.0           4    comida
# 4    mesa    NaN           5   veiculo
#
#   produto  preco  quantidade categoria
# 0   carro   23.0           1   veiculo
# 1  teste2   51.0           2   veiculo
# 2    bola  102.0           3    comida
# 3  teste4   28.0           4    comida
# 4    mesa   51.0           5   veiculo

# %%
import pandas as pd

# Criar um DataFrame
dados = {'A': [1,2,2,3,5] ,
'B': [10 , 2 , 10 , 4, 5] ,
'C': [1,2,3,4,5]}
df = pd.DataFrame(dados)
print ( df )
print()
for column in df:
    print(df[column])
    dupli = df[column].duplicated()
    print(dupli)

    print("------------------")
# Out:
#    A   B  C
# 0  1  10  1
# 1  2   2  2
# 2  2  10  3
# 3  3   4  4
# 4  5   5  5
#
# 0    1
# 1    2
# 2    2
# 3    3
# 4    5
# Name: A, dtype: int64
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: A, dtype: bool
# ------------------
# 0    10
# 1     2
# 2    10
# 3     4
# 4     5
# Name: B, dtype: int64
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: B, dtype: bool
# ------------------
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: C, dtype: int64
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: C, dtype: bool
# ------------------

# %%
import pandas as pd

# Criar um DataFrame
dados = {'produto': ['carro','teste2','bola','teste4','mesa'] ,
'preco': [23 , np.nan , 102 , 28, np.nan] ,
'quantidade': [10,2,3,4,5],
'categoria':['veiculo','veiculo','comida','comida','veiculo']         }
df = pd.DataFrame(dados)
print ( df )
print()

pivot_table = df.pivot_table(values="quantidade", index="categoria",aggfunc="sum")
print(pivot_table)
# Out:
#   produto  preco  quantidade categoria
# 0   carro   23.0          10   veiculo
# 1  teste2    NaN           2   veiculo
# 2    bola  102.0           3    comida
# 3  teste4   28.0           4    comida
# 4    mesa    NaN           5   veiculo
#
#            quantidade
# categoria
# comida              7
# veiculo            17

# %%
import pandas as pd

# Criar um DataFrame
dados = {'produto': ['carro','teste2','bola','teste4','mesa'] ,
'preco': [23 , np.nan , 102 , 28, np.nan] ,
'quantidade': [10,2,3,4,5],
'categoria':['veiculo','veiculo','comida','comida','veiculo']         }
df = pd.DataFrame(dados)
print ( df )
print()
dados2 = {'produto': ['carro','teste2','bola','teste4','mesa'] ,
'desconto': [23 , 45 , 102 , 28, 45]}
df2 = pd.DataFrame(dados2)
print()
df3 = pd.merge(df,df2,on='produto')

print(df3)
# Out:
#   produto  preco  quantidade categoria
# 0   carro   23.0          10   veiculo
# 1  teste2    NaN           2   veiculo
# 2    bola  102.0           3    comida
# 3  teste4   28.0           4    comida
# 4    mesa    NaN           5   veiculo
#
#
#   produto  preco  quantidade categoria  desconto
# 0   carro   23.0          10   veiculo        23
# 1  teste2    NaN           2   veiculo        45
# 2    bola  102.0           3    comida       102
# 3  teste4   28.0           4    comida        28
# 4    mesa    NaN           5   veiculo        45

# %%
import pandas as pd

# Criar um DataFrame
dados = {'produto': [pd.NaT,'teste2','bola','teste4','mesa'] ,
'preco': [10 , np.nan , 30 , 40, np.nan] ,
'quantidade': [10,2,3,4,5],
'categoria':['veiculo','veiculo','comida','comida','veiculo']         }
df = pd.DataFrame(dados)
print ( df )
print()
df2 = df.interpolate()
print(df2)
# Out:
#   produto  preco  quantidade categoria
# 0     NaT   10.0          10   veiculo
# 1  teste2    NaN           2   veiculo
# 2    bola   30.0           3    comida
# 3  teste4   40.0           4    comida
# 4    mesa    NaN           5   veiculo
#
#   produto  preco  quantidade categoria
# 0     NaT   10.0          10   veiculo
# 1  teste2   20.0           2   veiculo
# 2    bola   30.0           3    comida
# 3  teste4   40.0           4    comida
# 4    mesa   40.0           5   veiculo
# <ipython-input-14-072df94fd59f>:11: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df2 = df.interpolate()

# %%
dados2 = {'sexo': ['homem','homem','mulher','mulher','mulher'] ,
'idade': [23 , 45 , 102 , 28, 45]}
df2 = pd.DataFrame(dados2)
print(df2)
df2.plot.bar(x="sexo",y="idade")
# Out:
#      sexo  idade
# 0   homem     23
# 1   homem     45
# 2  mulher    102
# 3  mulher     28
# 4  mulher     45
# <Axes: xlabel='sexo'>

# %%
import pandas as pd

# Criar um DataFrame
dados = {'produto': ['carro','teste2','bola','teste4','mesa'] ,
'preco': [23 , 120 , 102 , 28, 5] ,
'quantidade': [1,2,3,4,5]}
df = pd.DataFrame(dados)
print ( df )
print()
total = df.quantidade * df.preco
print(total)
df["total"] = total
df["imposto"] = total * 0.05
print()
print(df)
# Out:
#   produto  preco  quantidade
# 0   carro     23           1
# 1  teste2    120           2
# 2    bola    102           3
# 3  teste4     28           4
# 4    mesa      5           5
#
# 0     23
# 1    240
# 2    306
# 3    112
# 4     25
# dtype: int64
#
#   produto  preco  quantidade  total  imposto
# 0   carro     23           1     23     1.15
# 1  teste2    120           2    240    12.00
# 2    bola    102           3    306    15.30
# 3  teste4     28           4    112     5.60
# 4    mesa      5           5     25     1.25

# %%
import pandas as pd

# Criar um DataFrame
dados = {'produto': ['carro','teste2','bola','teste4','mesa'] ,
'preco': [23 , 120 , 102 , 28, 5] ,
'quantidade': [1,2,3,4,5]}
df = pd.DataFrame(dados)

print()
total = df.quantidade * df.preco

df["total"] = total
df["imposto"] = total * 0.05
print()
print(df)
print()
df = df[df['produto'].str.startswith('b')]
print(df)
# Out:
#   produto  preco  quantidade  total  imposto
# 0   carro     23           1     23     1.15
# 1  teste2    120           2    240    12.00
# 2    bola    102           3    306    15.30
# 3  teste4     28           4    112     5.60
# 4    mesa      5           5     25     1.25
#
#   produto  preco  quantidade  total  imposto
# 2    bola    102           3    306     15.3

# %%
dados = {"a": [1,2,3,4], "b": [5,6,4,7],"c":[5,7,8,4]}
print(dados)
df = pd.DataFrame(dados)
print()
print(df)
print()
df2 = df.mean()
print(df2)
# Out:
# {'a': [1, 2, 3, 4], 'b': [5, 6, 4, 7], 'c': [5, 7, 8, 4]}
#
#    a  b  c
# 0  1  5  5
# 1  2  6  7
# 2  3  4  8
# 3  4  7  4
#
# a    2.5
# b    5.5
# c    6.0
# dtype: float64

# %%
dados = {"sexo": ["Masc","Fem","Fem","Masc"], "idade": [5,6,4,7]}
df = pd.DataFrame(dados)
print(df)
dfg = df.groupby("sexo")["idade"].median()
print()
print(dfg)
# Out:
#    sexo  idade
# 0  Masc      5
# 1   Fem      6
# 2   Fem      4
# 3  Masc      7
#
# sexo
# Fem     5.0
# Masc    6.0
# Name: idade, dtype: float64
